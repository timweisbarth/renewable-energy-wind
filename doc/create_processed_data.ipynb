# %%
import sys

sys.path.append("./../src/")

import data_loader as dl


dl.load_kelmarsh_data(from_raw=True)
dl.load_uebb_data(from_raw=True)
dl.load_ueps_data(from_raw=True)

print("Loaded data was saved to the doc/processed/ folder")
# Out:
#                      wind_speed_nacelle_max  sonic_wind_speed  tilt_Y  \
# Time
# 2013-08-01 00:00:00                     8.4             7.499 -0.7679
# 2013-08-01 00:10:00                     8.1             6.902 -0.7535
# 2013-08-01 00:20:00                     7.7             7.448 -0.7489
# 2013-08-01 00:30:00                     8.2             7.392 -0.7585
# 2013-08-01 00:40:00                     8.7             7.474 -0.7569
# ...                                     ...               ...     ...
# 2014-07-31 23:10:00                     9.3             8.420  0.0000
# 2014-07-31 23:20:00                     8.5             8.530  0.0000
# 2014-07-31 23:30:00                     9.5             8.670  0.0000
# 2014-07-31 23:40:00                     9.5             8.520  0.0000
# 2014-07-31 23:50:00                     9.4             8.280  0.0000
#
#                      logger_temperature  ws_w_corrected  tilt_X_std  tilt_X  \
# Time
# 2013-08-01 00:00:00               27.84             NaN      0.0594  0.5733
# 2013-08-01 00:10:00               27.88             NaN      0.0616  0.5687
# 2013-08-01 00:20:00               27.91             NaN      0.0640  0.5711
# 2013-08-01 00:30:00               27.93             NaN      0.0578  0.5712
# 2013-08-01 00:40:00               27.94             NaN      0.0601  0.5698
# ...                                 ...             ...         ...     ...
# 2014-07-31 23:10:00               27.60        0.128240      0.0000  0.0000
# 2014-07-31 23:20:00               27.63        0.110550      0.0000  0.0000
# 2014-07-31 23:30:00               27.63        0.092862      0.0000  0.0000
# 2014-07-31 23:40:00               27.63        0.075173      0.0000  0.0000
# 2014-07-31 23:50:00               27.62        0.057484      0.0000  0.0000
#
#                      active_power_total_min  wind_speed_nacelle    ws_u  ...  \
# Time                                                                     ...
# 2013-08-01 00:00:00                    76.0                 6.4 -6.4509  ...
# 2013-08-01 00:10:00                    81.0                 6.5 -5.6882  ...
# 2013-08-01 00:20:00                    81.0                 6.0 -6.6356  ...
# 2013-08-01 00:30:00                    91.0                 6.3 -6.3432  ...
# 2013-08-01 00:40:00                    96.0                 6.6 -6.5482  ...
# ...                                     ...                 ...     ...  ...
# 2014-07-31 23:10:00                   136.0                 7.6 -8.2825  ...
# 2014-07-31 23:20:00                   168.0                 7.6 -8.3745  ...
# 2014-07-31 23:30:00                   202.0                 8.2 -8.6088  ...
# 2014-07-31 23:40:00                   187.0                 8.0 -8.4197  ...
# 2014-07-31 23:50:00                   173.0                 8.0 -8.1757  ...
#
#                      lidar_ws_v1  lidar_ws_w1  lidar_availability1  \
# Time
# 2013-08-01 00:00:00          NaN          NaN                  NaN
# 2013-08-01 00:10:00          NaN          NaN                  NaN
# 2013-08-01 00:20:00          NaN          NaN                  NaN
# 2013-08-01 00:30:00          NaN          NaN                  NaN
# 2013-08-01 00:40:00          NaN          NaN                  NaN
# ...                          ...          ...                  ...
# 2014-07-31 23:10:00     0.574167     0.164000                100.0
# 2014-07-31 23:20:00     0.884667     0.314167                100.0
# 2014-07-31 23:30:00     1.581833     0.143500                100.0
# 2014-07-31 23:40:00     1.245500     0.156167                100.0
# 2014-07-31 23:50:00     0.609083     0.150167                100.0
#
#                      lidar_wind_speed2  lidar_wind_direction2  \
# Time
# 2013-08-01 00:00:00                NaN                    NaN
# 2013-08-01 00:10:00                NaN                    NaN
# 2013-08-01 00:20:00                NaN                    NaN
# 2013-08-01 00:30:00                NaN                    NaN
# 2013-08-01 00:40:00                NaN                    NaN
# ...                                ...                    ...
# 2014-07-31 23:10:00           7.924286              97.007143
# 2014-07-31 23:20:00           8.030000              98.692857
# 2014-07-31 23:30:00           8.124286             100.221429
# 2014-07-31 23:40:00           8.035714              98.721429
# 2014-07-31 23:50:00           7.896429              96.735714
#
#                      lidar_wind_speed_std2  lidar_ws_u2  lidar_ws_v2  \
# Time
# 2013-08-01 00:00:00                    NaN          NaN          NaN
# 2013-08-01 00:10:00                    NaN          NaN          NaN
# 2013-08-01 00:20:00                    NaN          NaN          NaN
# 2013-08-01 00:30:00                    NaN          NaN          NaN
# 2013-08-01 00:40:00                    NaN          NaN          NaN
# ...                                    ...          ...          ...
# 2014-07-31 23:10:00               0.633571    -7.839643     0.963643
# 2014-07-31 23:20:00               0.752857    -7.892357     1.204071
# 2014-07-31 23:30:00               0.757857    -7.949643     1.434786
# 2014-07-31 23:40:00               0.901429    -7.856929     1.205571
# 2014-07-31 23:50:00               0.852857    -7.795571     0.924429
#
#                      lidar_ws_w2  lidar_availability2
# Time
# 2013-08-01 00:00:00          NaN                  NaN
# 2013-08-01 00:10:00          NaN                  NaN
# 2013-08-01 00:20:00          NaN                  NaN
# 2013-08-01 00:30:00          NaN                  NaN
# 2013-08-01 00:40:00          NaN                  NaN
# ...                          ...                  ...
# 2014-07-31 23:10:00    -0.009571           100.000000
# 2014-07-31 23:20:00     0.226071           100.000000
# 2014-07-31 23:30:00     0.130071           100.000000
# 2014-07-31 23:40:00     0.127786           100.000000
# 2014-07-31 23:50:00     0.041429            98.960714
#
# [52560 rows x 69 columns]
